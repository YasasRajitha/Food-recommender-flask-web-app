# %%
import pandas as pd
pd.options.mode.chained_assignment = None 
import numpy as np
import csv
# Out:
# /tmp/ipykernel_6000/3609074589.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
recipe=pd.read_csv('RAW_recipes.csv')

# %%
df=pd.DataFrame(recipe)
df
# Out:
#         Unnamed: 0                                          name      id  \
# 0                0    arriba   baked winter squash mexican style  137739
# 1                1              a bit different  breakfast pizza   31490
# 2                2                     all in the kitchen  chili  112140
# 3                3                            alouette  potatoes   59389
# 4                4            amish  tomato ketchup  for canning   44061
# ...            ...                                           ...     ...
# 231632      231632                                   zydeco soup  486161
# 231633      231633                              zydeco spice mix  493372
# 231634      231634                     zydeco ya ya deviled eggs  308080
# 231635      231635        cookies by design   cookies on a stick  298512
# 231636      231636  cookies by design   sugar shortbread cookies  298509
#
#         minutes  contributor_id   submitted  \
# 0            55           47892  2005-09-16
# 1            30           26278  2002-06-17
# 2           130          196586  2005-02-25
# 3            45           68585  2003-04-14
# 4           190           41706  2002-10-25
# ...         ...             ...         ...
# 231632       60          227978  2012-08-29
# 231633        5         1500678  2013-01-09
# 231634       40           37779  2008-06-07
# 231635       29          506822  2008-04-15
# 231636       20          506822  2008-04-15
#
#                                                      tags  \
# 0       ['60-minutes-or-less', 'time-to-make', 'course...
# 1       ['30-minutes-or-less', 'time-to-make', 'course...
# 2       ['time-to-make', 'course', 'preparation', 'mai...
# 3       ['60-minutes-or-less', 'time-to-make', 'course...
# 4       ['weeknight', 'time-to-make', 'course', 'main-...
# ...                                                   ...
# 231632  ['ham', '60-minutes-or-less', 'time-to-make', ...
# 231633  ['15-minutes-or-less', 'time-to-make', 'course...
# 231634  ['60-minutes-or-less', 'time-to-make', 'course...
# 231635  ['30-minutes-or-less', 'time-to-make', 'course...
# 231636  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                           nutrition  n_steps  \
# 0             [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1         [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2        [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3         [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4         [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
# ...                                             ...      ...
# 231632  [415.2, 26.0, 34.0, 26.0, 44.0, 21.0, 15.0]        7
# 231633        [14.8, 0.0, 2.0, 58.0, 1.0, 0.0, 1.0]        1
# 231634         [59.2, 6.0, 2.0, 3.0, 6.0, 5.0, 0.0]        7
# 231635    [188.0, 11.0, 57.0, 11.0, 7.0, 21.0, 9.0]        9
# 231636     [174.9, 14.0, 33.0, 4.0, 4.0, 11.0, 6.0]        5
#
#                                                     steps  \
# 0       ['make a choice and proceed with recipe', 'dep...
# 1       ['preheat oven to 425 degrees f', 'press dough...
# 2       ['brown ground beef in large pot', 'add choppe...
# 3       ['place potatoes in a large pot of lightly sal...
# 4       ['mix all ingredients& boil for 2 1 / 2 hours ...
# ...                                                   ...
# 231632  ['heat oil in a 4-quart dutch oven', 'add cele...
# 231633        ['mix all ingredients together thoroughly']
# 231634  ['in a bowl , combine the mashed yolks and may...
# 231635  ['place melted butter in a large mixing bowl a...
# 231636  ['whip sugar and shortening in a large bowl , ...
#
#                                               description  \
# 0       autumn is my favorite time of year to cook! th...
# 1       this recipe calls for the crust to be prebaked...
# 2       this modified version of 'mom's' chili was a h...
# 3       this is a super easy, great tasting, make ahea...
# 4       my dh's amish mother raised him on this recipe...
# ...                                                   ...
# 231632  this is a delicious soup that i originally fou...
# 231633    this spice mix will make your taste buds dance!
# 231634                          deviled eggs, cajun-style
# 231635  i've heard of the 'cookies by design' company,...
# 231636  i've heard of the 'cookies by design' company,...
#
#                                               ingredients  n_ingredients  \
# 0       ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1       ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2       ['ground beef', 'yellow onions', 'diced tomato...             13
# 3       ['spreadable cheese with garlic and herbs', 'n...             11
# 4       ['tomato juice', 'apple cider vinegar', 'sugar...              8
# ...                                                   ...            ...
# 231632  ['celery', 'onion', 'green sweet pepper', 'gar...             22
# 231633  ['paprika', 'salt', 'garlic powder', 'onion po...             13
# 231634  ['hard-cooked eggs', 'mayonnaise', 'dijon must...              8
# 231635  ['butter', 'eagle brand condensed milk', 'ligh...             10
# 231636  ['granulated sugar', 'shortening', 'eggs', 'fl...              7
#
#        food type    cal
# 0        Healthy   51.5
# 1        Healthy  173.4
# 2        Healthy  269.8
# 3            Veg  368.1
# 4            Veg  352.9
# ...          ...    ...
# 231632   Non-veg  415.2
# 231633       Veg   14.8
# 231634   Healthy   59.2
# 231635   Healthy  188.0
# 231636   Healthy  174.9
#
# [231637 rows x 15 columns]

# %%
food=input('type of food o')

# %%
time=input('how long do you want to cook?')

# %%
nam=[]
mins=[]
nut=[]
setp=[]
des=[]
ind=[]


for i in df.index:
    if(df['food type'][i]==food and (int(df['minutes'][i])<int(time) or int(df['minutes'][i])==int(time))):
        nam.append(df['name'][i])
        mins.append(df['minutes'][i])
        nut.append(df['nutrition'][i])
        setp.append(df['steps'][i])
        des.append(df['description'][i])
        ind.append(df['ingredients'][i])

# %%
list_of_tuples = list(zip(nam, mins,nut,setp,des,ind)) 
df3 = pd.DataFrame(list_of_tuples, columns = ['Name', 'Minutes','Nutritient','Steps','Description','Ingridients'])

# %%
df3
# Out:
#                                                     Name  Minutes  \
# 0                                apple a day  milk shake        0
# 1                            berry  good sandwich spread        5
# 2                       emotional balance  spice mixture       10
# 3                     healthy for them  yogurt popsicles       10
# 4                              momma s special  marinade       10
# ...                                                  ...      ...
# 17129  zucchini with green peppercorns  lemon and par...       10
# 17130               zucchini with jalapeno monterey jack       10
# 17131                 zucchini with pine nuts and orange       10
# 17132                 zucchini  pignoli and raisin salad       10
# 17133                  zwiebeln salat  swiss onion salad       10
#
#                                       Nutritient  \
# 0       [160.2, 10.0, 55.0, 3.0, 9.0, 20.0, 7.0]
# 1          [79.2, 3.0, 58.0, 0.0, 0.0, 6.0, 5.0]
# 2       [182.7, 11.0, 4.0, 1.0, 13.0, 4.0, 10.0]
# 3         [164.6, 3.0, 5.0, 1.0, 4.0, 6.0, 11.0]
# 4       [199.2, 31.0, 6.0, 10.0, 1.0, 13.0, 1.0]
# ...                                          ...
# 17129       [43.1, 5.0, 3.0, 0.0, 1.0, 2.0, 1.0]
# 17130   [125.6, 13.0, 7.0, 6.0, 16.0, 27.0, 1.0]
# 17131      [73.7, 8.0, 13.0, 0.0, 2.0, 3.0, 1.0]
# 17132   [251.8, 31.0, 48.0, 0.0, 7.0, 11.0, 5.0]
# 17133  [113.5, 11.0, 17.0, 19.0, 2.0, 24.0, 3.0]
#
#                                                    Steps  \
# 0      ['combine ingredients in blender', 'cover and ...
# 1      ['in medium size bowl , coarsely mash cranberr...
# 2      ['mix the spices together and store in an airt...
# 3      ['mix all the ingredients using a blender', 'p...
# 4      ['depending on how much meat i have i usually ...
# ...                                                  ...
# 17129  ['whisk together the lemon juice , olive oil ,...
# 17130  ['spread the zucchini in a microwave-safe dish...
# 17131  ['fry onions in oil for 1 minute then add zucc...
# 17132  ['cut the zucchini into narrow strips', 'add t...
# 17133  ['melt butter in a saucepan', 'add onions and ...
#
#                                              Description  \
# 0                                                    NaN
# 1      horseradish is one of my favorite condiments a...
# 2      really an effective spice blend...i got it in ...
# 3      my children and their friends ask for my homem...
# 4      we usually use with chicken. my neices ask for...
# ...                                                  ...
# 17129  saw this on foodtv's cooking thin show. it is ...
# 17130                                  simple and yummy!
# 17131  a great way to use up zucchini (which can be a...
# 17132  from diane seed's mediterranean dishes. meant ...
# 17133  adapted from pan american's compete round the ...
#
#                                              Ingridients
# 0      ['milk', 'vanilla ice cream', 'frozen apple ju...
# 1      ['whole berry cranberry sauce', 'sour cream', ...
# 2      ['ground black pepper', 'ground ginger', 'grou...
# 3      ['milk', 'frozen juice concentrate', 'plain yo...
# 4      ['lemon juice', 'oil', 'worcestershire sauce',...
# ...                                                  ...
# 17129  ['lemon', 'extra virgin olive oil', 'salt', 'b...
# 17130  ['zucchini', 'monterey jack pepper cheese', 'a...
# 17131  ['spring onions', 'olive oil', 'zucchini', 'pi...
# 17132  ['zucchini', 'extra virgin olive oil', 'pine n...
# 17133   ['butter', 'onions', 'flour', 'salt', 'vinegar']
#
# [17134 rows x 6 columns]

# %%
df3.sample(n=3)
# Out:
#                                Name  Minutes  \
# 11983           pomegranate coolers       10
# 8205     james  s blackberry cowboy        5
# 11780  pineapple raspberry smoothie        2
#
#                                      Nutritient  \
# 11983     [66.1, 0.0, 64.0, 0.0, 0.0, 0.0, 5.0]
# 8205   [189.9, 0.0, 169.0, 0.0, 0.0, 0.0, 16.0]
# 11780  [184.8, 1.0, 145.0, 0.0, 4.0, 0.0, 15.0]
#
#                                                    Steps  \
# 11983  ['in a pitcher , muddle the mint with a wooden...
# 8205   ['fill a tall glass 1 / 2 full of ice', 'add p...
# 11780  ['place ingredients in a blender & blend until...
#
#                                              Description  \
# 11983                                        rachael ray
# 8205   my son jimbo was drinking a roy rodgers and go...
# 11780  another recipe that i found in the 2003 cookbo...
#
#                                              Ingridients
# 11983  ['of fresh mint', 'pomegranate juice', 'fresh ...
# 8205         ['pepsi', 'grenadine', 'blackberry brandy']
# 11780  ['apricot nectar', 'pineapple', 'raspberries',...
